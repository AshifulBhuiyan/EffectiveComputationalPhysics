# %% [markdown]
# # Analysis and Visualization
#
# - while series can be stored in CSV, complex structured data typically requires standarized database formats.
#
# - telesdcope data uses Fliexible Image Transport System (FITS)
# - nuclear physics deal with particle interaction probabilities called cross sections and use the Evaluated Nuclear Data File (ENDF).
#
# ### NumPy
# - due to their power, many solutions involve NumPy arrays
#     - data structures that hold numbers
# - one way to transform a file into a NumPy array is with the `loadtxt` fn.
# - plain-text files holding colunns of text delkimited by commas, spaces, or tabs can be loaded directly into a NumPy array

# %%
import numpy as np
decays_arr = np.loadtxt('./data/decays.csv', delimiter=',', skiprows=1)
decays_arr
# Out:
# array([[0.00000000e+00, 1.00000000e+01],
#        [1.00000000e+00, 1.35335283e+00],
#        [2.00000000e+00, 1.83156389e-01],
#        [3.00000000e+00, 2.47875220e-02],
#        [4.00000000e+00, 3.35462600e-03],
#        [5.00000000e+00, 4.53999000e-04],
#        [6.00000000e+00, 6.14420000e-05],
#        [7.00000000e+00, 8.31500000e-06],
#        [8.00000000e+00, 1.12600000e-06],
#        [9.00000000e+00, 1.52000000e-07]])

# %% [markdown]
# ### PyTables
# - provides tools for converting HDF5 into analysis-ready NumPy arrays
#
# ### Pandas
# - easiest to use and most broadly applicable of all data analysis tools in Python
# - can handle: CSV, Excel, HDF, SQL, JSON, HTML, Stata, Clipboard, Pickle

# %%
import pandas as pd
decays_df = pd.read_csv('./data/decays.csv')
decays_df
# once loaded can be easily converted to other supported formats:
# decays_df.to_hdf('./data/decays.h5', 'experimental')
# Out:
#    Time (s)    Decays (#)
# 0         0  1.000000e+01
# 1         1  1.353353e+00
# 2         2  1.831564e-01
# 3         3  2.478752e-02
# 4         4  3.354626e-03
# 5         5  4.539990e-04
# 6         6  6.144200e-05
# 7         7  8.315000e-06
# 8         8  1.126000e-06
# 9         9  1.520000e-07

# %% [markdown]
# ### Blaze
# - capable of converting data from format to format
# - CSV data can be dealt with as a Blaze data descriptor or as a Blaze `Table` object

# %%
import blaze as bz
csv_data = bz.CSV('./data/decays.csv')
decays_tb = bz.Table(csv_data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import blaze as bz
#       2 csv_data = bz.CSV('./data/decays.csv')
#       3 decays_tb = bz.Table(csv_data)
#
# File ~/.local/lib/python3.10/site-packages/blaze/__init__.py:9
#       6     pass
#       8 from pandas import DataFrame
# ----> 9 from odo import odo, convert, append, drop, resource
#      10 from odo.backends.csv import CSV
#      11 from odo.backends.json import JSON, JSONLines
#
# File ~/.local/lib/python3.10/site-packages/odo/__init__.py:12
#       9 halt_ordering()  # Turn off multipledispatch ordering
#      11 from .utils import ignoring
# ---> 12 from .convert import convert
#      13 from .append import append
#      14 from .resource import resource
#
# File ~/.local/lib/python3.10/site-packages/odo/convert.py:7
#       5 from datashape.predicates import isscalar
# ...

# %% [markdown]
# ### Missing Data
# - pandas is useful

# %%
decay_df = pd.read_csv('./data/many_decays.csv')
decay_df.count()
# Out:
# Time      50
# Decays    46
# dtype: int64

# %%
decay_df.dropna
# Out:
# <bound method DataFrame.dropna of                           Time        Decays
# 0   2014-11-08T05:19:31.561782  1.000000e+01
# 1   2014-11-08T05:19:32.561782  1.353353e+00
# 2   2014-11-08T05:19:33.561782  1.831564e-01
# 3   2014-11-08T05:19:34.561782  2.478752e-02
# 4   2014-11-08T05:19:35.561782  3.354626e-03
# 5   2014-11-08T05:19:36.561782  4.539993e-04
# 6   2014-11-08T05:19:37.561782  6.144212e-05
# 7   2014-11-08T05:19:38.561782  8.315287e-06
# 8   2014-11-08T05:19:39.561782  1.125352e-06
# 9   2014-11-08T05:19:40.561782  1.522998e-07
# 10  2014-11-08T05:19:41.561782  2.061154e-08
# 11  2014-11-08T05:19:42.561782  2.789468e-09
# 12  2014-11-08T05:19:43.561782  3.775135e-10
# 13  2014-11-08T05:19:44.561782  5.109089e-11
# 14  2014-11-08T05:19:45.561782  6.914400e-12
# 15  2014-11-08T05:19:46.561782  9.357623e-13
# 16  2014-11-08T05:19:47.561782  2.000000e+00
# 17  2014-11-08T05:19:48.561782  2.000000e+00
# 18  2014-11-08T05:19:49.561782  2.000000e+00
# ...

# %% [markdown]
# ### Analysis
# - packages within the SciPy and SciKits ecosystem complement the main `numpy`, `scipy` and `pandas` packages
# - For Astronomy and astrophysics:
#     - Astropy
#     - SpacePy
#     - SunPy
# - Geophysics
#     - OSGeo: GIS data import/export and anaylsis
#     - Basemap: 2D mapping
# - Engineering
#     - PyNE: toolkit for nuclear engineering
#     - scikit-aero: aeronautical engineering calculations
# - Mathmeatics
#     - SymPy: symbolic mathematics in Python
# - Neuroscience
#     - NIPY: neuroimaging in Python
# - Quantum
#     - QuTIP
#     - PyQuante
#
#
# ### Model-Driven Analysis:
# - Numerical Analysis
#
# ### Data-Driven Analysis
# - methods such as:
#     - clustering algorithms,
#     - machine learning processes
#         - scikit-learn
#         - PyBrain
#         - Monte
#         - PyPR
#         - scipy-cluster
#     - exotic statistic methods
#         - Statsmodels
#         - PyBayes
#
# ### Visualization
#
# - `gnuplot`
#     - simple plots
# - `matplotlib`
#     - powerful plotting library
# - `Bokeh`
#     - produces interactive plots
# - Inkspace
#     - software for hand editing of scalable vector graphics

# %% [markdown]
# ### Gnuplot
#
# - not a python tool
# - launched with `gnuplot`

# %% [raw]
# #decay_plot.gnuplot
# set title 'Decays'
# set ylabel 'Decays '
# set xlabel 'Time (s)'
# set grid
# set term svg
# set output 'plot_gnuplot.svg'
# plot 'decays.csv' every ::1 using 1:2 with lines

# %% [markdown]
# ### matplotlib

# %%
import numpy as np

decaydata =np.loadtxt('./data/decays.csv', delimiter= ",", skiprows=1)

time = decaydata[:,0]
decays = decaydata[:,1]

import pylab as plt
#import matplotlib.pyplot as plt

plt.plot(time, decays)
plt.xlabel('Time (s)')
plt.ylabel('Decays')
plt.title('Decays')
plt.grid(True)
plt.savefig("decays_matplotlib.png")

# %% [markdown]
# ### Poster created with matplotlib

# %%
#!/usr/bin/env python
# Import various necessary Python and matplotlib packages
import numpy as np
import matplotlib.cm as cm
from matplotlib.pyplot import figure, show, rc
from matplotlib.patches import Ellipse

# Create a square figure on which to place the plot
fig = figure(figsize=(8,8))

# Create square axes to hold the circular polar plot
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], polar=True)

# Generate 20 colored, angular wedges for the polar plot
N = 20
theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
bars = ax.bar(theta, radii, width=width, bottom=0.0)
for r,bar in zip(radii, bars):
    bar.set_facecolor(cm.jet(r/10.))
    bar.set_alpha(0.5)

# Using dictionaries, create a color scheme for the text boxes
bbox_args = dict(boxstyle="round, pad=0.9", fc="green", alpha=0.5)
bbox_white = dict(boxstyle="round, pad=0.9", fc="1", alpha=0.9)
patch_white = dict(boxstyle="round, pad=1", fc="1", ec="1")

# Create various boxes with text annotations in them at specific
# x and y coordinates
ax.annotate(" ",
    xy=(.5,.93),
    xycoords='figure fraction',
    ha="center", va="center",
    bbox=patch_white)
ax.annotate('Matplotlib and the Python Ecosystem for Scientific Computing',
    xy=(.5,.95),
    xycoords='figure fraction',
    xytext=(0, 0), textcoords='offset points',
    size=15,
    ha="center", va="center",
    bbox=bbox_args)
ax.annotate('Author and Lead Developer \n of Matplotlib ',
    xy=(.5,.82),
    xycoords='figure fraction',
    xytext=(0, 0), textcoords='offset points',
    ha="center", va="center",
    bbox=bbox_args)
ax.annotate('John D. Hunter',
    xy=(.5,.89),
    xycoords='figure fraction',
    xytext=(0, 0), textcoords='offset points',
    size=15,
    ha="center", va="center",
    bbox=bbox_white)
ax.annotate('Friday November 5th \n 2:00 pm \n1106ME ',
    xy=(.5,.25),
    xycoords='figure fraction',
    xytext=(0, 0), textcoords='offset points',
    size=15,
    ha="center", va="center",
    bbox=bbox_args)
ax.annotate('Sponsored by: \n The Hacker Within, \n'
'The University Lectures Committee, \n The Department of '
'Medical Physics\n and \n The American Nuclear Society',
    xy=(.78,.1),
    xycoords='figure fraction',
    xytext=(0, 0), textcoords='offset points',
    size=9,
    ha="center", va="center",
    bbox=bbox_args)
fig.savefig("plot.pdf")

# %% [markdown]
# ### Bokeh
# - simple matplot-lib friendly API that can generate interactive plots appropriate for the Web
# - abstracts from matplotlib syntax, makingf user experience celeaner

# %%
#decay_bokeh.py
import numpy as np
# import the Bokeh plotting tools
from bokeh import plotting as bp

# as in the matplotlib example, load decays.csv into a NumPy array
decaydata = np.loadtxt('./data/decays.csv',delimiter=",",skiprows=1)

# provide handles for the x and y columns
time = decaydata[:,0]
decays = decaydata[:,1]

# define some output file metadata
bp.output_file("decays.html", title="Experiment 1 Radioactivity")

# create a figure with fun Internet-friendly features (optional)
bp.figure(tools="pan,wheel_zoom,box_zoom,reset,previewsave")

# on that figure, create a line plot
bp.line(time, decays, x_axis_label="Time (s)", y_axis_label="Decays (#)",
color='#1F78B4', legend='Decays per second')

# additional customization to the figure can be specified separately
bp.curplot().title = "Decays"
bp.grid().grid_line_alpha=0.3

# open a browser
bp.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 17
#      14 bp.output_file("decays.html", title="Experiment 1 Radioactivity")
#      16 # create a figure with fun Internet-friendly features (optional)
# ---> 17 bp.figure(tools="pan,wheel_zoom,box_zoom,reset,previewsave")
#      19 # on that figure, create a line plot
#      20 bp.line(time, decays, x_axis_label="Time (s)", y_axis_label="Decays (#)",
#      21 color='#1F78B4', legend='Decays per second')
#
# File ~/Python/April/.conda/lib/python3.10/site-packages/bokeh/plotting/_figure.py:203, in figure.__init__(self, *arg, **kw)
#     200 process_axis_and_grid(self, opts.x_axis_type, opts.x_axis_location, opts.x_minor_ticks, opts.x_axis_label, self.x_range, 0)
#     201 process_axis_and_grid(self, opts.y_axis_type, opts.y_axis_location, opts.y_minor_ticks, opts.y_axis_label, self.y_range, 1)
# ...
